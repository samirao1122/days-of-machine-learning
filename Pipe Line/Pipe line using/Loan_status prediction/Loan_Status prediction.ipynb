# %%
import pickle

# %%
model=pickle.load(open("file2.pkl","rb"))
model
# Out:
# Pipeline(steps=[('t1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('t1',
#                                                   OrdinalEncoder(categories=[['Male',
#                                                                               'Female'],
#                                                                              ['Yes',
#                                                                               'No']]),
#                                                   [0, 1])])),
#                 ('t2',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('t2',
#                                                   OrdinalEncoder(categories=[['Graduate',
#                                                                               'Not '
#                                                                               'Graduate'],
# ...

# %%
value=[["Male","Yes",1,"Graduate","No",12841,10968,349,360,1,"Urban"]]

# %%
value
# Out:
# [['Male', 'Yes', 1, 'Graduate', 'No', 12841, 10968, 349, 360, 1, 'Urban']]

# %%
model.predict(value)
# Out:
# C:\Users\wwrao\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but OrdinalEncoder was fitted with feature names
#   warnings.warn(
# array([1])

# %%
value1=[["Male","Yes",0,"Graduate","No",1853,2840,114,360,1,"Urban"]]
value1
# Out:
# [['Male', 'Yes', 0, 'Graduate', 'No', 1853, 2840, 114, 360, 1, 'Urban']]

# %%
model.predict(value1)
# Out:
# C:\Users\wwrao\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but OrdinalEncoder was fitted with feature names
#   warnings.warn(
# array([0])

# %%
value2=[["Male","No",0,"Graduate","Yes",1853,2840,114,360,1,"Urban"]]
value2
# Out:
# [['Male', 'No', 0, 'Graduate', 'Yes', 1853, 2840, 114, 360, 1, 'Urban']]

# %%
model.predict(value2)
# Out:
# C:\Users\wwrao\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but OrdinalEncoder was fitted with feature names
#   warnings.warn(
# array([0])

# %%
value=[["Male","No",0,"Graduate","No",4950,0,125,360,1,"Urban"]]
