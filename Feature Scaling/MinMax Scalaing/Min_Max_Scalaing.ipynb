# %%
import pandas as pd

# %%
dataset=pd.read_csv(r"C:\Users\wwrao\OneDrive\Documents\loan_data.csv")

# %%
dataset.drop(columns=["credit.policy","purpose","log.annual.inc","int.rate","inq.last.6mths","not.fully.paid","pub.rec","revol.util","installment","dti"],inplace=True,axis=1)

# %%
dataset.head()
# Out:
#    fico  days.with.cr.line  revol.bal  delinq.2yrs
# 0   737        5639.958333      28854            0
# 1   707        2760.000000      33623            0
# 2   682        4710.000000       3511            0
# 3   712        2699.958333      33667            0
# 4   667        4066.000000       4740            1

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mm=MinMaxScaler()

# %% [markdown]
# <h3>fico Column</h3>

# %%
mm.fit(dataset[["fico"]])
# Out:
# MinMaxScaler()

# %%
fico=mm.transform(dataset[["fico"]])

# %%
fig,(ax1,ax2,ax3,ax4)=plt.subplots(ncols=4,figsize=(10,2))
ax1.scatter(dataset["fico"],dataset["delinq.2yrs"])
ax1.set_title("before Scaling")

ax2.scatter(fico,dataset["delinq.2yrs"],color="green")
ax2.set_title("After Scaling")

ax3.hist(dataset["fico"])
ax3.set_title("before Scaling")

ax4.hist(fico,color="red")
ax4.set_title("After Scaling")

plt.tight_layout()

# %% [markdown]
# <h3>days.with.cr.line</h3>

# %%
mm.fit(dataset[["days.with.cr.line"]])
# Out:
# MinMaxScaler()

# %%
days_with_cr_line=mm.transform(dataset[["days.with.cr.line"]])

# %%
fig,(ax1,ax2,ax3,ax4)=plt.subplots(ncols=4,figsize=(10,2))
ax1.scatter(dataset["days.with.cr.line"],dataset["delinq.2yrs"])
ax1.set_title("before Scaling")

ax2.scatter(days_with_cr_line,dataset["delinq.2yrs"],color="green")
ax2.set_title("After Scaling")

ax3.hist(dataset["days.with.cr.line"])
ax3.set_title("before Scaling")

ax4.hist(days_with_cr_line,color="brown")
ax4.set_title("After Scaling")

plt.tight_layout()

# %% [markdown]
# <h3>revol.bal</h3>

# %%
mm.fit(dataset[["revol.bal"]])
# Out:
# MinMaxScaler()

# %%
revol_bal=mm.transform(dataset[["revol.bal"]])

# %%
fig,(ax1,ax2,ax3,ax4)=plt.subplots(ncols=4,figsize=(10,2))
ax1.scatter(dataset["revol.bal"],dataset["delinq.2yrs"])
ax1.set_title("before Scaling")

ax2.scatter(revol_bal,dataset["delinq.2yrs"],color="green")
ax2.set_title("After Scaling")

ax3.hist(dataset["revol.bal"])
ax3.set_title("before Scaling")

ax4.hist(revol_bal,color="red")
ax4.set_title("After Scaling")

plt.tight_layout()
